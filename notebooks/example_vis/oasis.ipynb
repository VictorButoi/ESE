# %%
import sys
sys.path.append('/storage/vbutoi/projects')
sys.path.append('/storage/vbutoi/libraries')
sys.path.append('/storage/vbutoi/projects/ESE')
sys.path.append('/storage/vbutoi/projects/UniverSeg')

from ionpy.analysis import ResultsLoader
from ese.experiment.experiment import CalibrationExperiment
import seaborn as sns
sns.set_style("darkgrid")

import os 
os.environ['DATAPATH'] = ':'.join((
       '/storage/vbutoi/datasets',
))
os.environ["CUDA_VISIBLE_DEVICES"] = '1' 

# %load_ext yamlmagic
# %load_ext autoreload
# %autoreload 2

# %%
# Results loader object does everything
rs = ResultsLoader()
root = "/storage/vbutoi/scratch/ESE"

# %%
path = f"{root}/WMH_aug_runs"

dfc = rs.load_configs(
    path,
    properties=False,
)

df = rs.load_metrics(dfc)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
dfc
# Out:
#                           data     annotator  axis dataset  slice_batch_size  \
# 0  ese.experiment.datasets.WMH  observer_o12     0     WMH                 1
# 1  ese.experiment.datasets.WMH  observer_o12     0     WMH                 1
# 2  ese.experiment.datasets.WMH  observer_o12     0     WMH                 1
# 3  ese.experiment.datasets.WMH  observer_o12     0     WMH                 1
# 4  ese.experiment.datasets.WMH  observer_o12     0     WMH                 1
# 5  ese.experiment.datasets.WMH  observer_o12     0     WMH                16
# 6  ese.experiment.datasets.WMH  observer_o12     0     WMH                 8
# 7  ese.experiment.datasets.WMH  observer_o12     0     WMH                16
# 8  ese.experiment.datasets.WMH  observer_o12     0     WMH                 1
# 9  ese.experiment.datasets.WMH  observer_o12     0     WMH                 8
#
#   slicing       task  batch_size  num_workers  pin_memory  ...  \
# 0   dense  Amsterdam           8            4       False  ...
# 1   dense  Amsterdam           1            4       False  ...
# 2   dense  Amsterdam           8            4       False  ...
# 3   dense  Amsterdam           1            4       False  ...
# 4   dense  Amsterdam           1            4       False  ...
# 5   dense  Amsterdam           1            4       False  ...
# 6   dense  Amsterdam           1            4       False  ...
# 7   dense  Amsterdam           1            4       False  ...
# 8   dense  Amsterdam           1            4       False  ...
# 9   dense  Amsterdam           1            4       False  ...
#
#    convs_per_block           filters in_channels  out_channels  \
# 0                2  (64, 64, 64, 64)           1             1
# 1                2  (64, 64, 64, 64)           1             1
# 2                2  (64, 64, 64, 64)           1             1
# 3                2  (64, 64, 64, 64)           1             1
# 4                2  (64, 64, 64, 64)           1             1
# 5                2  (64, 64, 64, 64)           1             1
# 6                2  (64, 64, 64, 64)           1             1
# 7                2  (64, 64, 64, 64)           1             1
# 8                2  (64, 64, 64, 64)           1             1
# 9                2  (64, 64, 64, 64)           1             1
#
#               optim      lr epochs  eval_freq  \
# 0  torch.optim.Adam  0.0003    500         50
# 1  torch.optim.Adam  0.0003    500         50
# 2  torch.optim.Adam  0.0003    500         50
# 3  torch.optim.Adam  0.0003    500         50
# 4  torch.optim.Adam  0.0003    500         50
# 5  torch.optim.Adam  0.0003    500         50
# 6  torch.optim.Adam  0.0003    500         50
# 7  torch.optim.Adam  0.0003    500         50
# 8  torch.optim.Adam  0.0003    500         50
# 9  torch.optim.Adam  0.0003    500         50
#
#                                                 path  \
# 0  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 1  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 2  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 3  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 4  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 5  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 6  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 7  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 8  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
# 9  /storage/vbutoi/scratch/ESE/WMH_aug_runs/20230...
#
#                                        augmentations
# 0                                                NaN
# 1                                                NaN
# 2  [{"RandomAffine": {"degrees": [0, 360], "p": 0...
# 3  [{"RandomAffine": {"degrees": [0, 360], "p": 0...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  [{"RandomAffine": {"degrees": [0, 360], "p": 0...
# 8  [{"RandomAffine": {"degrees": [0, 360], "p": 0...
# 9  [{"RandomAffine": {"degrees": [0, 360], "p": 0...
#
# [10 rows x 25 columns]

# %%
best_exp = rs.get_experiment(
    df=df,
    exp_class=CalibrationExperiment,
    metric="val-dice_score",
    checkpoint="max-val-dice_score",
    device="cuda"
)

# %%
best_exp.vis_loss_curves(height=8)

# %%
best_exp.vis_predictions(phase='val', num_examples=5)
