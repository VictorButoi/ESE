# %%
# Random Imports
import os
import sys
sys.path.append('/storage/vbutoi/projects')
sys.path.append('/storage/vbutoi/libraries')
sys.path.append('/storage/vbutoi/projects/ESE')
sys.path.append('/storage/vbutoi/projects/UniverSeg')

# Regular schema dictates that we put DATAPATH
os.environ['DATAPATH'] = ':'.join((
       '/storage/vbutoi/datasets',
))
os.environ['WANDB_NOTEBOOK_NAME'] = 'train.ipynb'

# %load_ext yamlmagic
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Define said jobs

# %%
# %%yaml default_cfg
#
# experiment:
#   seed: 42
#
# dataloader:
#   batch_size: 1
#   num_workers: 1
#   pin_memory: True
#
# optim:
#   _class: torch.optim.Adam
#   lr: 3.0e-4
#   weight_decay: 0.0
#
# train:
#   epochs: 1000
#   eval_freq: 10
#   augmentations: None
#   pretrained_dir: None
#
# log:
#   checkpoint_freq: 5
#   root: '?'
#   metrics:
#     dice_score:
#       _fn: ionpy.metrics.dice_score
#       from_logits: True
#       batch_reduction: 'mean'
#       ignore_empty_labels: '?'
#       ignore_index: '?' # Ignore background class when reporting.
#
# ######################
# # Cross-Entropy Loss #
# ######################
# loss_func:
#   _class: ionpy.loss.PixelCELoss
#   from_logits: True
#   batch_reduction: 'mean'
#
# #############
# # Dice Loss #
# #############
# # loss_func:
# #   _class: ionpy.loss.SoftDiceLoss
# #   from_logits: True
# #   batch_reduction: 'mean'
# #   ignore_index: '?'
# #   ignore_empty_labels: '?'

# %%
# %%yaml model_cfg
#
# model:
#   _class: ese.experiment.models.UNet
#   filters: '?'
#   convs_per_block: 3

# %%
# %%yaml dataset_cfg
#
# #######
# # WMH #
# #######
# data:
#   _class: ese.experiment.datasets.WMH
#   axis: 0
#   task: Amsterdam
#   slicing: dense
#   annotator: observer_o12
#   num_slices: 1
#   in_channels: 1
#   out_channels: 2
#   version: 0.2
#   preload: False
#
# ##################
# # OASIS 4-Labels #
# ##################
# # data:
# #   _class: ese.experiment.datasets.OASIS
# #   axis: 0
# #   label_set: label4
# #   slicing: central
# #   num_slices: 1
# #   in_channels: 1
# #   out_channels: 5
# #   central_width: 32
# #   version: 0.1
# #   preload: False
#
# ###################
# # OASIS 35-Labels #
# ###################
# # data:
# #   _class: ese.experiment.datasets.OASIS
# #   axis: 0
# #   label_set: label35
# #   slicing: central
# #   num_slices: 1
# #   in_channels: 1
# #   out_channels: 36
# #   central_width: 32
# #   version: 0.1
# #   preload: False
#
# ##############
# # CityScapes #
# ##############
# # data:
# #   _class: ese.experiment.datasets.CityScapes
# #   in_channels: 3
# #   out_channels: 35
#
# ##############
# # OxfordPets #
# ##############
# # data:
# #   _class: ese.experiment.datasets.OxfordPets
# #   preload: True
# #   version: 0.1
# #   num_classes: all
# #   in_channels: 3
# #   out_channels: 38 # 37 + 1 (background)
#
# #####################
# # Binary OxfordPets #
# #####################
# # data:
# #   _class: ese.experiment.datasets.BinaryPets
# #   preload: True
# #   version: 0.1
# #   in_channels: 3
# #   out_channels: 2

# %%
# %%yaml lite_aug_cfg
#
# - RandomAffine:
#     p: 0.5
#     degrees: [0, 360]
#     translate: [0, 0.2]
#     scale: [0.8, 1.1]
# - RandomVariableElasticTransform:
#     p: 0.75
#     alpha: [1, 2]
#     sigma: [8, 10]
# - RandomHorizontalFlip:
#     p: 0.5
# - RandomVerticalFlip:
#     p: 0.5

# %%
# %%yaml standard_aug_cfg 

# - RandomCrop:
#     _class: ese.experiment.augmentation.transforms.RandomCropSegmentation
#     size: [256, 256]

# %%
# %%yaml callbacks_cfg
#
# callbacks:
#   step:
#     - ese.experiment.callbacks.ShowPredictions
#   epoch:
#     - ese.experiment.callbacks.WandbLogger
#     - ionpy.callbacks.ETA
#     - ionpy.callbacks.JobProgress
#     - ionpy.callbacks.TerminateOnNaN
#     - ionpy.callbacks.PrintLogged
#     - ionpy.callbacks.ModelCheckpoint:
#         monitor: dice_score
#         phase: val

# %% [markdown]
# ## Debug Station

# %%
# Setup direcrtories
train_root = '/storage/vbutoi/scratch/ESE/training'

# WMH CONFIG
exp_name = '01_02_24_DebugUtil'
mod_filters = [64, 64, 64, 64, 64]
dl_bs = 8

# BINARY PETS CONFIG
# exp_name = '11_20_23_BinaryPets_CrossEntropy'
# mod_filters = [64, 64, 64, 64, 64]
# dl_bs = 8

# OASIS 4-Label CONFIG
# exp_name = '11_20_23_OASIS4_CrossEntropy'
# mod_filters = [64, 64, 64, 64, 64]
# dl_bs = 8

# OASIS 35-Label CONFIG
# exp_name = '11_20_23_OASIS35_CrossEntropy'
# mod_filters = [64, 64, 64, 64, 64]
# dl_bs = 8

# CityScapes CONFIG
# exp_name = '11_20_23_CityScapes_CrossEntropy'
# mod_filters = [64, 64, 64, 64, 64]
# dl_bs = 8

# Setup the root.
exp_root = f'{train_root}/{exp_name}'

# Create the ablation options
option_set = [
    {
        'log.root': [exp_root],
        'log.metrics.dice_score.ignore_empty_labels': [False], # Set False for WMH, True otherwise.
        'log.metrics.dice_score.ignore_index': [0], # Set 0 for WMH, otherwise is a choice.
        # 'loss_func.ignore_empty_labels': [False], # Set False for WMH, True otherwise. USE FOR DICE
        # 'loss_func.ignore_index': [0], # Set 0 for WMH, otherwise is a choice. USE FOR DICE
        'dataloader.batch_size': [dl_bs],
        'model.filters': [mod_filters]
    },
]

# %%
from ese.scripts.utils import get_option_product
from ionpy.util import Config

# Assemble base config
base_cfg = Config(default_cfg).update([model_cfg, dataset_cfg, callbacks_cfg])

# Get the configs
cfgs = get_option_product(exp_name, option_set, base_cfg)

# %%
len(cfgs)

# %% [markdown]
# ## Running Jobs

# %%
# FOR DEBUGGING
from ese.experiment.experiment import run_ese_exp, CalibrationExperiment

run_ese_exp(
    config=cfgs[0], 
    experiment_class=CalibrationExperiment,
    gpu='3',
    run_name='debug',
    show_examples=False,
    track_wandb=False
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 # FOR DEBUGGING
#       2 from ese.experiment.experiment import run_ese_exp, CalibrationExperiment
# ----> 4 run_ese_exp(
#       5     config=cfgs[0],
#       6     experiment_class=CalibrationExperiment,
#       7     gpu='3',
#       8     run_name='debug',
#       9     show_examples=False,
#      10     track_wandb=False
#      11 )
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/pydantic/decorator.py:40, in pydantic.decorator.validate_arguments.validate.wrapper_function()
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/pydantic/decorator.py:134, in pydantic.decorator.ValidatedFunction.call()
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/pydantic/decorator.py:206, in pydantic.decorator.ValidatedFunction.execute()
#
# File /storage/vbutoi/projects/ESE/ese/experiment/experiment/runner.py:36, in run_ese_exp(config, experiment_class, gpu, run_name, show_examples, track_wandb)
#      33     cfg["callbacks"]["epoch"].remove("ese.experiment.callbacks.WandbLogger")
#      35 # Run the experiment.
# ---> 36 slite.run_exp(
#      37     exp_class=experiment_class,
#      38     exp_object=Config(cfg),
#      39     gpu=gpu,
#      40 )
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/pydantic/decorator.py:40, in pydantic.decorator.validate_arguments.validate.wrapper_function()
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/pydantic/decorator.py:134, in pydantic.decorator.ValidatedFunction.call()
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/pydantic/decorator.py:206, in pydantic.decorator.ValidatedFunction.execute()
#
# File /storage/vbutoi/projects/ionpy/slite/runner.py:33, in run_exp(exp_class, exp_object, gpu)
#      30     exp = exp_class(exp_object)
#      32 # Run the experiment.
# ---> 33 exp.run()
#
# File /storage/vbutoi/projects/ESE/ese/experiment/experiment/ese_exp.py:151, in CalibrationExperiment.run(self)
#     150 def run(self):
# --> 151     super().run()
#
# File /storage/vbutoi/projects/ionpy/experiment/train.py:176, in TrainExperiment.run(self)
#     174 print(f"Start epoch {epoch}")
#     175 self._epoch = epoch
# --> 176 self.run_phase("train", epoch)
#     177 if eval_freq > 0 and (epoch % eval_freq == 0 or epoch == epochs - 1):
#     178     self.run_phase("val", epoch)
#
# File /storage/vbutoi/projects/ionpy/experiment/train.py:203, in TrainExperiment.run_phase(self, phase, epoch)
#     199 meters = MeterDict()
#     201 with torch.set_grad_enabled(grad_enabled):
#     202     # with torch.inference_mode(not grad_enabled):
# --> 203     for batch_idx, batch in enumerate(dl):
#     204         outputs = self.run_step(
#     205             batch_idx=batch_idx,
#     206             batch=batch,
#    (...)
#     210             phase=phase
#     211         )
#     212         metrics = self.compute_metrics(outputs)
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1316, in _MultiProcessingDataLoaderIter._next_data(self)
#    1313     return self._process_data(data)
#    1315 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1316 idx, data = self._get_data()
#    1317 self._tasks_outstanding -= 1
#    1318 if self._dataset_kind == _DatasetKind.Iterable:
#    1319     # Check for _IterableDatasetStopIteration
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1272, in _MultiProcessingDataLoaderIter._get_data(self)
#    1270 elif self._pin_memory:
#    1271     while self._pin_memory_thread.is_alive():
# -> 1272         success, data = self._try_get_data()
#    1273         if success:
#    1274             return data
#
# File ~/envs/UniverSegTF/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1120, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1107 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1108     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1109     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1117     # Returns a 2-tuple:
#    1118     #   (bool: whether successfully get data, any: data if successful else None)
#    1119     try:
# -> 1120         data = self._data_queue.get(timeout=timeout)
#    1121         return (True, data)
#    1122     except Exception as e:
#    1123         # At timeout and error, we manually check whether any worker has
#    1124         # failed. Note that this is the only mechanism for Windows to detect
#    1125         # worker failures.
#
# File ~/envs/UniverSegTF/lib/python3.9/queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File ~/envs/UniverSegTF/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# FOR SUBMISSION
# from ese.experiment.experiment import run_ese_exp, CalibrationExperiment

# submit_ese_exps(
#     exp_root=exp_root,
#     experiment_class=run_ese_exp,
#     config_list=cfgs,
#     available_gpus=['0'],
#     wandb=True
# )
