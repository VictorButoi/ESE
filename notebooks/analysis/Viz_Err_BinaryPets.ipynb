# %%
import sys
sys.path.append('/storage/vbutoi/projects')
sys.path.append('/storage/vbutoi/libraries')
sys.path.append('/storage/vbutoi/projects/ESE')
sys.path.append('/storage/vbutoi/projects/UniverSeg')

from ionpy.analysis import ResultsLoader
from ese.experiment.experiment import CalibrationExperiment
import seaborn as sns
sns.set_style("darkgrid")

import os 
os.environ['DATAPATH'] = ':'.join((
       '/storage/vbutoi/datasets',
))
os.environ["CUDA_VISIBLE_DEVICES"] = '3' 

# %load_ext yamlmagic
# %load_ext autoreload
# %autoreload 2

# %%
# Results loader object does everything
rs = ResultsLoader()
root = "/storage/vbutoi/scratch/ESE"

# %%
path = f"{root}/09_18_23_BinaryPetsPilot"

dfc = rs.load_configs(
    path,
    properties=False,
)

df = rs.load_metrics(dfc)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
best_exp = rs.get_experiment(
    df=df,
    exp_class=CalibrationExperiment,
    metric="val-dice_score",
    checkpoint="max-val-dice_score",
    device="cuda"
)

# %%
best_exp.vis_loss_curves(height=6)

# %%
# %%yaml dataset_cfg
#
# _class: ese.experiment.datasets.BinaryPets
# split: cal
# preload: True
# version: 0.1

# %%
from ionpy.experiment.util import absolute_import
from torch.utils.data import DataLoader

dataset_cls = absolute_import(dataset_cfg.pop("_class"))
BinaryPet_Dataset = dataset_cls(**dataset_cfg)
binarypets_dataloader = DataLoader(BinaryPet_Dataset, batch_size=1, shuffle=False, drop_last=False)

# %%
from ionpy.util.torchutils import to_device
import torch
from tqdm.notebook import tqdm

def get_dataset_perf(
        exp, 
        dataloader, 
        ):

    items = []
    with torch.no_grad():
        for _, batch in tqdm(enumerate(dataloader), total=len(dataloader)):
            
            # Get your image label pair and define some regions.
            x, y = to_device(batch, exp.device)
            # Get the prediction
            yhat = exp.model(x)  
            # Extract predictions
            soft_pred = torch.softmax(yhat, axis=1)
            hard_pred = torch.argmax(soft_pred, axis=1)
            # Get the confidence map
            conf_map = torch.max(soft_pred, axis=1)[0]
            # Wrap it in an item
            items.append({
                "image": x.cpu().squeeze(),
                "label_map": y.cpu().squeeze(),
                "conf_map": conf_map.cpu().squeeze(),
                "pred_map": hard_pred.cpu().squeeze(),
            })

    return items
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb Cell 8 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bahoy/storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import einops
#       <a href='vscode-notebook-cell://ssh-remote%2Bahoy/storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from tqdm.notebook import tqdm
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bahoy/storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> from ese.experiment.metrics.grouping import group_by_distance, group_by_label, group_by_region_size
#       <a href='vscode-notebook-cell://ssh-remote%2Bahoy/storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> from ionpy.util.torchutils import to_device
#       <a href='vscode-notebook-cell://ssh-remote%2Bahoy/storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> def get_dataset_perf(
#       <a href='vscode-notebook-cell://ssh-remote%2Bahoy/storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>         exp,
#       <a href='vscode-notebook-cell://ssh-remote%2Bahoy/storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>         dataloader,
#      <a href='vscode-notebook-cell://ssh-remote%2Bahoy/storage/vbutoi/projects/ESE/notebooks/analysis/Viz_Err_BinaryPets.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>         ):
#
# ImportError: cannot import name 'group_by_distance' from 'ese.experiment.metrics.grouping' (unknown location)

# %%
# val_perf is a dict where each item is the subj id
# with the y, ypred, yloss, ydice
predictions_list = get_dataset_perf(
    exp=best_exp, 
    dataloader=binarypets_dataloader
    )
