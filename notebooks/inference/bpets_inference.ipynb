# %%
import sys
sys.path.append('/storage/vbutoi/projects')
sys.path.append('/storage/vbutoi/libraries')
sys.path.append('/storage/vbutoi/projects/ESE')
sys.path.append('/storage/vbutoi/projects/UniverSeg')
import torch
torch.set_printoptions(linewidth=200)
import seaborn as sns
sns.set_style("darkgrid")

import os 
os.environ['DATAPATH'] = ':'.join((
       '/storage/vbutoi/datasets',
))

# Results loader object does everything
from ionpy.analysis import ResultsLoader
from pathlib import Path
root = Path("/storage/vbutoi/scratch/ESE")
rs = ResultsLoader()

# For using code without restarting.
# %load_ext autoreload
# %autoreload 
# For using yaml configs.
# %load_ext yamlmagic

# %%
training_exp_name = "training/09_18_23_BinaryPetsPilot"

dfc = rs.load_configs(
    root / training_exp_name,
    properties=False,
)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
dfc
# Out:
#   augmentations                                data  in_channels  \
# 0          None  ese.experiment.datasets.BinaryPets            3
# 1          None  ese.experiment.datasets.BinaryPets            3
# 2          None  ese.experiment.datasets.BinaryPets            3
# 3          None  ese.experiment.datasets.BinaryPets            3
# 4          None  ese.experiment.datasets.BinaryPets            3
# 5          None  ese.experiment.datasets.BinaryPets            3
# 6          None  ese.experiment.datasets.BinaryPets            3
# 7          None  ese.experiment.datasets.BinaryPets            3
#
#    out_channels  preload  version  batch_size  num_workers  pin_memory  seed  \
# 0             2     True      0.1           8            2       False    42
# 1             2     True      0.1           4            2       False    42
# 2             2     True      0.1          16            2       False    42
# 3             2     True      0.1           4            2       False    42
# 4             2     True      0.1           8            2       False    42
# 5             2     True      0.1           8            2       False    42
# 6             2     True      0.1           8            2       False    42
# 7             2     True      0.1          16            2       False    42
#
#    ...                       model convs_per_block               filters  \
# 0  ...  ese.experiment.models.UNet               3  (64, 64, 64, 64, 64)
# 1  ...  ese.experiment.models.UNet               3  (32, 32, 32, 32, 32)
# 2  ...  ese.experiment.models.UNet               3  (32, 32, 32, 32, 32)
# 3  ...  ese.experiment.models.UNet               3  (64, 64, 64, 64, 64)
# 4  ...  ese.experiment.models.UNet               3  (32, 32, 32, 32, 32)
# 5  ...  ese.experiment.models.UNet               3  (32, 32, 32, 32, 32)
# 6  ...  ese.experiment.models.UNet               3  (64, 64, 64, 64, 64)
# 7  ...  ese.experiment.models.UNet               3  (64, 64, 64, 64, 64)
#
#               optim      lr weight_decay  train_augmentations epochs  \
# 0  torch.optim.Adam  0.0003          0.0                 None   1000
# 1  torch.optim.Adam  0.0003          0.0                 None   1000
# 2  torch.optim.Adam  0.0003          0.0                 None   1000
# 3  torch.optim.Adam  0.0003          0.0                 None   1000
# 4  torch.optim.Adam  0.0003          0.0                 None   1000
# 5  torch.optim.Adam  0.0003          0.0                 None   1000
# 6  torch.optim.Adam  0.0003          0.0                 None   1000
# 7  torch.optim.Adam  0.0003          0.0                 None   1000
#
#   eval_freq                                               path
# 0        10  /storage/vbutoi/scratch/ESE/training/09_18_23_...
# 1        10  /storage/vbutoi/scratch/ESE/training/09_18_23_...
# 2        10  /storage/vbutoi/scratch/ESE/training/09_18_23_...
# 3        10  /storage/vbutoi/scratch/ESE/training/09_18_23_...
# 4        10  /storage/vbutoi/scratch/ESE/training/09_18_23_...
# 5        10  /storage/vbutoi/scratch/ESE/training/09_18_23_...
# 6        10  /storage/vbutoi/scratch/ESE/training/09_18_23_...
# 7        10  /storage/vbutoi/scratch/ESE/training/09_18_23_...
#
# [8 rows x 25 columns]

# %%
# %%yaml inference_config
#
# log:
#     root: '?'
#     log_interval: 50
#     track_image_level: True
#     track_pixel_level: True
#
# model:
#     exp_root: '?'
#     num_workers: 1
#
# dataset:
#     split: '?'
#     input_type: image
#
# calibration:
#     conf_interval_start: 0.5
#     conf_interval_end: 1.0
#     num_bins: 10
#     neighborhood_width: 3
#
# score:
#     ignore_index: 0

# %%
# %%yaml cal_metrics_cfg
#
# cal_metrics:
#     - ECE:
#         func: ese.experiment.metrics.ECE
#     - TL_ECE:
#         func: ese.experiment.metrics.TL_ECE
#     - CW_ECE:
#         func: ese.experiment.metrics.CW_ECE
#     - SUME:
#         func: ese.experiment.metrics.SUME
#     - TL_SUME:
#         func: ese.experiment.metrics.TL_SUME
#     - CW_SUME:
#         func: ese.experiment.metrics.CW_SUME

# %%
from ionpy.util import dict_product, Config

# Need to define the experiment name
inference_exp_root = str(root / "inference/11_20_23_BinaryPets_Inference")

# Get the inference options.
##################################################
dataset_options = {
    'log.root': [inference_exp_root],
    'model.exp_root': [str(root / training_exp_name)],
    'dataset.split': ['cal'],
}

base_cfg = Config(inference_config).update(cal_metrics_cfg)

cfgs = []
for cfg_update in dict_product(dataset_options):
    new_cfg = base_cfg.update(cfg_update)
    cfgs.append(new_cfg)

# %%
# from ese.experiment.analysis.inference import get_cal_stats
# os.environ["CUDA_VISIBLE_DEVICES"] = '0'

# get_cal_stats(cfgs[0])

# %%
from ionpy.slite.submit import submit_jobs
from ese.experiment.analysis.inference import get_cal_stats

submit_jobs(
    exp_root=inference_exp_root,
    config_list=cfgs, 
    job_func=get_cal_stats,
    available_gpus=["1"]
    )
# Out:
# Initalized SliteRunner
# Submitted job id: 705341.
